# %%
# !pip install mokuro
# Out:
# Collecting mokuro
#   Downloading mokuro-0.2.2-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 kB 4.4 MB/s eta 0:00:00
# Collecting fire (from mokuro)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting loguru (from mokuro)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Collecting manga-ocr>=0.1.7 (from mokuro)
#   Downloading manga_ocr-0.1.14-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from mokuro) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mokuro) (2.0.2)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.12/dist-packages (from mokuro) (4.12.0.88)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from mokuro) (11.3.0)
# Collecting pyclipper (from mokuro)
#   Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mokuro) (2.32.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mokuro) (1.16.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from mokuro) (75.2.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from mokuro) (2.1.2)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from mokuro) (2.9.0+cu126)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (from mokuro) (1.5.1)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from mokuro) (0.24.0+cu126)
# Requirement already satisfied: transformers>=4.25.0 in /usr/local/lib/python3.12/dist-packages (from mokuro) (4.57.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from mokuro) (4.67.1)
# Collecting yattag (from mokuro)
#   Downloading yattag-1.16.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fugashi (from manga-ocr>=0.1.7->mokuro)
#   Downloading fugashi-1.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (7.3 kB)
# Collecting jaconv (from manga-ocr>=0.1.7->mokuro)
#   Downloading jaconv-0.4.1-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from manga-ocr>=0.1.7->mokuro) (1.11.0)
# Collecting unidic_lite (from manga-ocr>=0.1.7->mokuro)
#   Downloading unidic-lite-1.0.8.tar.gz (47.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.7.0->mokuro) (3.5.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.25.0->mokuro) (0.7.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->mokuro) (3.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mokuro) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mokuro) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mokuro) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mokuro) (2025.11.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.25.0->mokuro) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.7.0->mokuro) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.7.0->mokuro) (3.0.3)
# Downloading mokuro-0.2.2-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 14.5 MB/s eta 0:00:00
# Downloading manga_ocr-0.1.14-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.6 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 12.9 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.9 MB/s eta 0:00:00
# Downloading pyclipper-1.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (978 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 66.6 MB/s eta 0:00:00
# Downloading fugashi-1.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (694 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.9/694.9 kB 59.7 MB/s eta 0:00:00
# Downloading jaconv-0.4.1-py3-none-any.whl (15 kB)
# Building wheels for collected packages: yattag, unidic_lite
#   Building wheel for yattag (setup.py) ... done
#   Created wheel for yattag: filename=yattag-1.16.1-py3-none-any.whl size=15886 sha256=8d9a4cfa260576a3c2330b120ad9de281ab137c0ccdf2e5f23ce9f40ab7b2a2b
#   Stored in directory: /root/.cache/pip/wheels/d2/2f/52/049ff4f7c8c9c932b2ece7ec800d7facf2a141ac5ab0ce7e51
#   Building wheel for unidic_lite (setup.py) ... done
#   Created wheel for unidic_lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658817 sha256=d9d113a1768b3e4c21baffda5cb824df5ed895bb87aea16c2436149963ad4b48
#   Stored in directory: /root/.cache/pip/wheels/5e/1f/0f/4d43887e5476d956fae828ee9b6687becd5544d68b51ed633d
# Successfully built yattag unidic_lite
# Installing collected packages: yattag, unidic_lite, jaconv, pyclipper, loguru, fugashi, fire, manga-ocr, mokuro
# Successfully installed fire-0.7.1 fugashi-1.5.2 jaconv-0.4.1 loguru-0.7.3 manga-ocr-0.1.14 mokuro-0.2.2 pyclipper-1.4.0 unidic_lite-1.0.8 yattag-1.16.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# See https://github.com/kha-white/mokuro#usage for instructions on setting parameters

# %%
# !mokuro --parent_dir "/content/drive/MyDrive/manga"
# Out:
# 2025-12-25 03:03:01.709080: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766631781.730233    3778 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766631781.736413    3778 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766631781.751589    3778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766631781.751615    3778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766631781.751619    3778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766631781.751624    3778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-25 03:03:01.756123: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-25 03:03:08.762 | WARNING  | mokuro.run:run:55 - Legacy HTML output is deprecated and will not be further developed. It's recommended to use .mokuro format and web reader instead. Legacy HTML will be disabled by default in the future. To explicitly enable it, run with option --legacy-html.
# 2025-12-25 03:03:08.762 | INFO     | mokuro.run:run:63 - Scanning paths...
#
# Found 1 volumes:
#
# /content/drive/MyDrive/manga/isekai1 (unprocessed)
#
# Each of the paths above will be treated as one volume.
#
#
# Continue? [yes/no]yes
# 2025-12-25 03:03:34.999 | INFO     | mokuro.run:run:133 - Processing 1/1: /content/drive/MyDrive/manga/isekai1
# Processing pages...:   0% 0/161 [00:00<?, ?it/s]2025-12-25 03:03:35.062 | INFO     | mokuro.manga_page_ocr:__init__:41 - Initializing text detector, using device cuda
# 2025-12-25 03:03:35.063 | INFO     | mokuro.cache:_download_if_needed:22 - Downloading https://github.com/zyddnys/manga-image-translator/releases/download/beta-0.2.1/comictextdetector.pt
# 2025-12-25 03:03:38.479 | INFO     | mokuro.cache:_download_if_needed:30 - Finished downloading https://github.com/zyddnys/manga-image-translator/releases/download/beta-0.2.1/comictextdetector.pt
# 2025-12-25 03:03:39.791 | INFO     | manga_ocr.ocr:__init__:16 - Loading OCR model from kha-white/manga-ocr-base
#
# preprocessor_config.json: 100% 228/228 [00:00<00:00, 1.53MB/s]
#
# tokenizer_config.json: 100% 486/486 [00:00<00:00, 4.12MB/s]
#
# vocab.txt: 24.1kB [00:00, 46.0MB/s]
#
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 914kB/s]
#
# config.json: 77.5kB [00:00, 83.1MB/s]
#
# pytorch_model.bin:   0% 0.00/444M [00:00<?, ?B/s]
# pytorch_model.bin:   0% 24.5k/444M [00:01<9:13:24, 13.4kB/s]
# pytorch_model.bin:  17% 76.9M/444M [00:02<00:07, 52.3MB/s]
# pytorch_model.bin:  24% 109M/444M [00:02<00:05, 64.3MB/s]
# pytorch_model.bin:  40% 176M/444M [00:02<00:03, 88.4MB/s]
# pytorch_model.bin:  70% 310M/444M [00:03<00:00, 180MB/s]
# pytorch_model.bin:  85% 377M/444M [00:03<00:00, 195MB/s]
# pytorch_model.bin: 100% 444M/444M [00:03<00:00, 125MB/s]
# 2025-12-25 03:03:49.144 | INFO     | manga_ocr.ocr:__init__:22 - Using CUDA
#
# model.safetensors:   0% 0.00/444M [00:00<?, ?B/s]2025-12-25 03:03:50.831 | INFO     | manga_ocr.ocr:__init__:35 - OCR ready
#
# model.safetensors:   0% 573k/444M [00:01<18:57, 390kB/s]
# model.safetensors:  24% 109M/444M [00:01<00:03, 84.2MB/s]
# model.safetensors:  40% 176M/444M [00:02<00:02, 101MB/s]
# model.safetensors:  55% 243M/444M [00:02<00:01, 134MB/s]
# model.safetensors:  70% 310M/444M [00:02<00:00, 172MB/s]
# model.safetensors:  85% 377M/444M [00:02<00:00, 212MB/s]
# model.safetensors: 100% 444M/444M [00:03<00:00, 146MB/s]
# Processing pages...: 100% 161/161 [05:33<00:00,  2.07s/it]
# 2025-12-25 03:09:10.153 | INFO     | mokuro.run:run:146 - Processed successfully: 1/1
